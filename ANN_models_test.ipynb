# %% [markdown]
# # ANN Models Analysis

# %% [markdown]
# ## Model 1 : MSE = 0.2340

# %%
from IPython.display import display, Image
display(Image(filename='model_1.PNG'))

# %% [markdown]
# ## Model 2 : MSE = 0.2383

# %%
from IPython.display import display, Image
display(Image(filename='model_2.PNG'))

# %% [markdown]
# ## Model 3 : MSE = 0.2387

# %%
from IPython.display import display, Image
display(Image(filename='model_3.PNG'))

# %% [markdown]
# ## Model 4 : MSE = 0.2379

# %%
from IPython.display import display, Image
display(Image(filename='model_4.PNG'))

# %% [markdown]
# ## Model 5 : MSE = 0.2374

# %%
from IPython.display import display, Image
display(Image(filename='model_5.PNG'))
